# %%
# Import libraries
import xarray as xr
import rioxarray 
from pathlib import Path
import pandas as pd

# %%
# If you want to get min and max lat and long values for a particular country 
def get_bounding_box_max_min_lat_long_values(country_name, df_bounding_boxes):
    # Get min of lat and long for the country
    min_long = df_bounding_boxes[df_bounding_boxes['country'] == country_name]['longmin']
    min_lat = df_bounding_boxes[df_bounding_boxes['country'] == country_name]['latmin']
    # Get max of lat and long for the country
    max_long = df_bounding_boxes[df_bounding_boxes['country'] == country_name]['longmax']
    max_lat = df_bounding_boxes[df_bounding_boxes['country'] == country_name]['latmax']
    return  min_long, min_lat, max_long, max_lat

# %%
# Get xarray dataset from source
def get_xarray_dataset(path_to_dataset='SeasFire.zarr'):
    ds = xr.open_zarr(Path.home() / path_to_dataset)
    return ds

# %%
# Decide which country/location you want to plot from the names here 
def get_location_names(path_to_bounding_boxes_dataset='hdd1/akanksha/xarray/country-boundingboxes.csv'):
    df_bounding_boxes = pd.read_csv(Path.home() / path_to_bounding_boxes_dataset)
    country_names_list = df_bounding_boxes['country'].to_list()
    return country_names_list, df_bounding_boxes

# %%
# Clip the xarray dataset by getting min and max lat and long and then passing it through the rio built in functions to clip
def get_clipped_xarray_dataset(ds, country_name, df_bounding_boxes):
    # CRS code 
    dsc = ds.rio.write_crs(4326) # Need to specify this as Ilektra mentioned 
    
    # Get min of lat and long for the country  and  max of lat and long for the country
    min_long, min_lat, max_long, max_lat = get_bounding_box_max_min_lat_long_values(country_name, df_bounding_boxes)
    
    # Clip the dataset
    ds_clipped = dsc.rio.clip_box(minx= min_long, miny= min_lat, maxx= max_long,maxy= max_lat)
    
    return ds_clipped

# %%
# Initialise the datacube 
ds = get_xarray_dataset(path_to_dataset='SeasFire.zarr')

# Get the list of countries 
country_names_list, df_bounding_boxes = get_location_names(path_to_bounding_boxes_dataset='hdd1/akanksha/xarray/country-boundingboxes.csv')
country_names_list
# Out:
# ['Aruba',
#  'Antigua and Barbuda',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Algeria',
#  'Azerbaijan',
#  'Albania',
#  'Armenia',
#  'Andorra',
#  'Angola',
#  'Argentina',
#  'Australia',
#  'AT',
#  'Austria',
#  'AV',
#  'Bahrain',
#  'Barbados',
#  'Botswana',
#  'BD',
#  'Belgium',
#  'Bahamas',
#  'Bangladesh',
#  'Belize',
#  'Bosnia and H',
#  'Bolivia',
#  'Burma',
#  'Benin',
#  'Belarus',
#  'Solomon Isla',
#  'Brazil',
#  'BS',
#  'Bhutan',
#  'Bulgaria',
#  'BV',
#  'Brunei',
#  'Burundi',
#  'Canada',
#  'Cambodia',
#  'Chad',
#  'Sri Lanka',
#  'Republic of ',
#  'Democratic R',
#  'China',
#  'Chile',
#  'CJ',
#  'CK',
#  'Cameroon',
#  'Comoros',
#  'Colombia',
#  'CR',
#  'Costa Rica',
#  'Central Afri',
#  'Cuba',
#  'Cape Verde',
#  'CW',
#  'Cyprus',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Re',
#  'Ecuador',
#  'Egypt',
#  'Ireland',
#  'Equatorial G',
#  'Estonia',
#  'Eritrea',
#  'El Salvador',
#  'Ethiopia',
#  'EU',
#  'Czech Republ',
#  'FG',
#  'Finland',
#  'Fiji',
#  'FK',
#  'Federated St',
#  'FO',
#  'FP',
#  'France',
#  'FS',
#  'Gambia',
#  'Gabon',
#  'Georgia',
#  'Ghana',
#  'GI',
#  'Grenada',
#  'GK',
#  'GL',
#  'Germany',
#  'GO',
#  'GP',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'GZ',
#  'Haiti',
#  'HK',
#  'HM',
#  'Honduras',
#  'Croatia',
#  'Hungary',
#  'Iceland',
#  'Indonesia',
#  'IM',
#  'India',
#  'IO',
#  'IP',
#  'Iran',
#  'Israel',
#  'Italy',
#  "Côte d'Ivoi",
#  'Iraq',
#  'Japan',
#  'JE',
#  'Jamaica',
#  'JN',
#  'Jordan',
#  'JU',
#  'Kenya',
#  'Kyrgyzstan',
#  'North Korea',
#  'Kiribati',
#  'South Korea',
#  'KT',
#  'Kuwait',
#  'Kazakhstan',
#  'Laos',
#  'Lebanon',
#  'Latvia',
#  'Lithuania',
#  'Liberia',
#  'Slovakia',
#  'Liechtenstei',
#  'Lesotho',
#  'Luxembourg',
#  'Libya',
#  'Madagascar',
#  'MB',
#  'MC',
#  'Moldova',
#  'MF',
#  'Mongolia',
#  'MH',
#  'Malawi',
#  'Montenegro',
#  'Macedonia',
#  'Mali',
#  'Monaco',
#  'Morocco',
#  'Mauritius',
#  'Mauritania',
#  'Malta',
#  'Oman',
#  'Maldives',
#  'Mexico',
#  'Malaysia',
#  'Mozambique',
#  'NC',
#  'NE',
#  'NF',
#  'Niger',
#  'Vanuatu',
#  'Nigeria',
#  'Netherlands',
#  'NM',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'Suriname',
#  'NT',
#  'Nicaragua',
#  'New Zealand',
#  'OS',
#  'Paraguay',
#  'PC',
#  'Peru',
#  'PF',
#  'PG',
#  'Pakistan',
#  'Poland',
#  'Panama',
#  'Portugal',
#  'Papua New Gu',
#  'Palau',
#  'Guinea-Bissa',
#  'Qatar',
#  'Serbia',
#  'RE',
#  'Marshall Isl',
#  'Romania',
#  'Philippines',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'SB',
#  'Saint Kitts ',
#  'Seychelles',
#  'South Africa',
#  'Senegal',
#  'SH',
#  'Slovenia',
#  'Sierra Leone',
#  'San Marino',
#  'Singapore',
#  'Somalia',
#  'Spain',
#  'Saint Lucia',
#  'Sudan',
#  'SV',
#  'Sweden',
#  'SX',
#  'Syria',
#  'Switzerland',
#  'Trinidad and',
#  'TE',
#  'Thailand',
#  'Tajikistan',
#  'TK',
#  'TL',
#  'Tonga',
#  'Togo',
#  'Sao Tome and',
#  'Tunisia',
#  'East Timor',
#  'Turkey',
#  'Tuvalu',
#  'Taiwan',
#  'Turkmenistan',
#  'Tanzania',
#  'UF',
#  'Uganda',
#  'United Kingd',
#  'Ukraine',
#  'United State',
#  'Burkina Faso',
#  'Uruguay',
#  'Uzbekistan',
#  'Saint Vincen',
#  'Venezuela',
#  'VI',
#  'Vietnam',
#  'Holy See',
#  'Namibia',
#  'WE',
#  'WF',
#  'WI',
#  'Samoa',
#  'Swaziland',
#  'YI',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
# Decide country name 
country_name = 'France'

# %%
# Getting all datacube input and output variables for that country 
ds_clipped = get_clipped_xarray_dataset(ds, country_name, df_bounding_boxes)

# %%
# See the difference in size 
# ds represents the global dataset 
# ds_clipped represents the particular country 
ds_clipped
# Out:
# <xarray.Dataset>
# Dimensions:                         (latitude: 40, longitude: 60, time: 966)
# Coordinates:
#   * latitude                        (latitude) float64 51.12 50.88 ... 41.38
#   * longitude                       (longitude) float64 -5.125 -4.875 ... 9.625
#     spatial_ref                     int64 0
#   * time                            (time) datetime64[ns] 2001-01-01 ... 2021...
# Data variables: (12/54)
#     area                            (latitude, longitude) float32 dask.array<chunksize=(25, 21), meta=np.ndarray>
#     cams_co2fire                    (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     cams_frpfire                    (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     drought_code_max                (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     drought_code_mean               (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     fcci_ba                         (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     ...                              ...
#     t2m_max                         (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     t2m_mean                        (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     t2m_min                         (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     tp                              (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     vpd                             (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
#     ws10                            (time, latitude, longitude) float32 dask.array<chunksize=(966, 25, 21), meta=np.ndarray>
# Attributes:
#     description:  The SeasFire Cube is a scientific datacube for seasonal fir...
#     title:        SeasFire Cube: A Global Dataset for Seasonal Fire Modeling ...

# %%
ds_clipped['ndvi'].isel(time=0).plot()

# %%
ds_clipped['fcci_ba'].isel(time=27).plot()

# %%
ds_clipped['fcci_ba'].isel(time=31).plot()

# %%
ds_clipped['fcci_ba'].isel(time=35).plot()
